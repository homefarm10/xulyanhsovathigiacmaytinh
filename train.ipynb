# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.1/112.6 GB disk)

# %%
# Train YOLO26n on COCO8 for 3 epochs 
# !yolo train model=yolov8n.pt data="/content/drive/MyDrive/Xulyanhso/Student Behaviour Detection/data.yaml" epochs=150 imgsz=640
# Out:
# ...
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
